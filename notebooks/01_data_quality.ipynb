# %% [markdown]
# # Data quality review
# This notebook is a presentation layer over tested engine functions. It must not contain authoritative pipeline logic.

# %%
from aquanavai.config import load_scenario
scenario = load_scenario('south-florida-v1')
scenario.model_dump()
