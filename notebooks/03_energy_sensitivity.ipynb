# %% [markdown]
# # Energy sensitivity
# Use this notebook for reviewed sensitivity figures after experiment artifacts are generated.

# %%
from aquanavai.energy.vehicle import VehicleModel
speeds = [1.0, 1.25, 1.5, 1.75]
[(speed, VehicleModel(speed, 30, 44.44).total_power_w) for speed in speeds]
