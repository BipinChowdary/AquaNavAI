# %% [markdown]
# # Baseline comparison
# Distance Dijkstra and environmental A* share one graph and experiment contract. Proxy results are not scientific evidence.

# %%
from aquanavai.config import load_scenario, load_vehicle
from aquanavai.evaluation.runner import evaluate_scenario
bundle = evaluate_scenario(load_scenario('south-florida-v1'), load_vehicle())
len(bundle.results)
